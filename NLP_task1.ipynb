# %%
# Install required libraries:
# pip install requests beautifulsoup4 nltk

import requests
from bs4 import BeautifulSoup
import nltk as nltk
nltk.download('averaged_perceptron_tagger')
from nltk import pos_tag
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import re
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ual-laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ual-
# [nltk_data]     laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\ual-
# [nltk_data]     laptop\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from bs4 import BeautifulSoup

# Replace 'your_health_website_url' with the actual URL of the health-related website you want to scrape
base_url = 'https://www.healthline.com/'



# Function to get the text content from a webpage
def get_page_content(url):
    try:
        session = requests.Session()
        retry = Retry(connect=3, backoff_factor=0.5)
        adapter = HTTPAdapter(max_retries=retry)
        session.mount('http://', adapter)
        session.mount('https://', adapter)

        response = session.get(url)
        response.raise_for_status()  # Raise an error for bad responses (4xx and 5xx)
        soup = BeautifulSoup(response.text, 'html.parser')
        status_code = response.status_code
        print(f"Status Code: {status_code}")
        text_content = soup.get_text()
        return text_content
    except requests.exceptions.RequestException as e:
        print(f"Error accessing {url}: {e}")
        return None

# Function to get all the links from a webpage
def get_all_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        status_code = response.status_code
        print(f"Status Code: {status_code}")
        # Adjust the HTML structure based on the website you're scraping
        links = soup.find_all('a', href=True)
        # temp_links = [ a.replace('https://www.healthline.com/', '') for a in links]

        # Use a list comprehension to create the new list of links with the base URL
        new_links = ['https://www.healthline.com' + link['href'] for link in links]

        return new_links
    except requests.exceptions.RequestException as e:
        print(f"Error accessing {url}: {e}")
        return []

def scrape_website(base_url, max_pages=100):
    visited_urls = set()
    pages_to_visit = [base_url]
    pages_scraped = 0
    text_collection = []

    while pages_to_visit and pages_scraped < max_pages:
        current_url = pages_to_visit.pop(0)

        # Skip already visited URLs
        if current_url in visited_urls:
            if current_url == 'https://www.healthline.com':
                continue

        # Get text content from the current page
        text_content = get_page_content(current_url)
        print(f"Scraping {current_url}")
        text_collection.append(text_content)

        # Save or process the text content as needed
        # For example, you can save it to a file or process it further

        # Mark the current URL as visited
        visited_urls.add(current_url)

        # Get all links from the current page
        page_links = get_all_links(current_url)

        # Add new links to the list of pages to visit
        pages_to_visit.extend(page_links)

        # Update the counter for scraped pages
        pages_scraped += 1

    # Return the list of text content after scraping all pages
    return text_collection

# Start scraping (scrape up to 100 pages)
result_text_collection = scrape_website(base_url, max_pages=100)
# Out:
# Status Code: 200
# Scraping https://www.healthline.com/
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/conditions
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/breast-cancer
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/irritable-bowel-disease
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/migraine
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/multiple-sclerosis
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/rheumatoid-arthritis
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/type-2-diabetes
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/sponsored-topics
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/directory/topics
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/gerd
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/adhd
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/allergies
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/alzheimers-disease
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/bipolar-disorder
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/cancer
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/crohns-disease
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/chronic-pain
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/cold-flu
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/copd
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/depression
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/fibromyalgia
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/heart-disease
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/high-cholesterol
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/hiv-aids
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/high-blood-pressure-hypertension
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/managing-idiopathic-pulmonary-fibrosis
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/osteoarthritis
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/psoriasis
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/skin-disorders
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/sexually-transmitted-diseases
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/wellness
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/nutrition
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/fitness
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/skincare
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/sexual-health
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/program/wellness
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/mental-health
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/sleep
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/vitamin-and-supplement-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/sleep-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/mental-health-services-and-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/nutrition-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/at-home-testing-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/cbd-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/reviews/mens-health-products
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/series
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/content-series/fresh-food-fast
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/content-series/diagnosis-diaries
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/content-series/youre-not-alone
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/content-series/present-tense
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/video
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/video/youth-in-focus
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/nutrition/video/healthy-harvest
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/breast-cancer/metastatic-breast-cancer-artist-eye
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/video/future-of-health
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/newsletter-signup/mindfulness-challenge
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/newsletter-signup/sugar-challenge
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/newsletter-signup/move-your-body-challenge
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/newsletter-signup/gut-check-challenge
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/newsletter-signup/mood-foods-challenge
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/newsletter-signup/align-your-spine-challenge
# Status Code: 200
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0ADD710>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0F65D10>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/primary-care-doctors?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/primary-care-doctors?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBC890>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/primary-care-doctors?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/primary-care-doctors?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/primary-care-doctors?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F048C8D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/mental-health-professional?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/mental-health-professional?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0F67290>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/mental-health-professional?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/mental-health-professional?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/mental-health-professional?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0ADC190>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/obstetrics-gynecology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/obstetrics-gynecology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBEA50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/obstetrics-gynecology?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/obstetrics-gynecology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/obstetrics-gynecology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0F8CA10>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/dermatology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/dermatology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0ADD150>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/dermatology?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/dermatology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/dermatology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0F67050>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/neurology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/neurology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBF0D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/neurology?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/neurology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/neurology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBD890>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/cardiology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/cardiology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F08AE350>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/cardiology?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/cardiology?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/cardiology?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0F66310>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/orthopedic-surgery?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/orthopedic-surgery?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBC090>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://care.healthline.com/find-care/specialty/orthopedic-surgery?ref=global
# Error accessing https://www.healthline.comhttps://care.healthline.com/find-care/specialty/orthopedic-surgery?ref=global: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //care.healthline.com/find-care/specialty/orthopedic-surgery?ref=global (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBF290>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Status Code: 200
# Scraping https://www.healthline.com/nutrition/weight-management-quiz
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/depression/teenage-quiz
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/mental-health/quiz-are-you-a-workaholic#quiz-are-you-a-workaholic
# Status Code: 200
# Status Code: 200
# Scraping https://www.healthline.com/health/healthy-sleep/quiz-how-well-do-you-sleep
# Status Code: 200
# Error accessing https://www.healthline.comhttps://www.healthline.com/health-news: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/health-news (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F116A850>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/health-news
# Error accessing https://www.healthline.comhttps://www.healthline.com/health-news: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/health-news (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F1168110>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://activation.healthline.com/assessment/assessment/diets/prompt/1?v=1&tc=120226&subid=hl_dietfinder_1_: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //activation.healthline.com/assessment/assessment/diets/prompt/1?v=1&tc=120226&subid=hl_dietfinder_1_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0851350>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://activation.healthline.com/assessment/assessment/diets/prompt/1?v=1&tc=120226&subid=hl_dietfinder_1_
# Error accessing https://www.healthline.comhttps://activation.healthline.com/assessment/assessment/diets/prompt/1?v=1&tc=120226&subid=hl_dietfinder_1_: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //activation.healthline.com/assessment/assessment/diets/prompt/1?v=1&tc=120226&subid=hl_dietfinder_1_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F11685D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://activation.healthline.com/assessment/assessment/pregnancy-snacks/prompt/1?v=1: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //activation.healthline.com/assessment/assessment/pregnancy-snacks/prompt/1?v=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F16D2290>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://activation.healthline.com/assessment/assessment/pregnancy-snacks/prompt/1?v=1
# Error accessing https://www.healthline.comhttps://activation.healthline.com/assessment/assessment/pregnancy-snacks/prompt/1?v=1: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //activation.healthline.com/assessment/assessment/pregnancy-snacks/prompt/1?v=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0852990>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Status Code: 200
# Scraping https://www.healthline.com/drugs
# Status Code: 200
# Error accessing https://www.healthline.comhttps://www.healthline.com/directory/topics: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/directory/topics (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF401010>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/directory/topics
# Error accessing https://www.healthline.comhttps://www.healthline.com/directory/topics: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/directory/topics (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF400A10>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzy.com: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF403B10>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzy.com
# Error accessing https://www.healthline.comhttps://www.bezzy.com: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzy.com (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF401450>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzybc.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzybc.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDCD10>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzybc.com/?utm_source=healthline&utm_medium=nav-bar-connections
# Error accessing https://www.healthline.comhttps://www.bezzybc.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzybc.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDE210>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzyibd.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzyibd.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EE7D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzyibd.com/?utm_source=healthline&utm_medium=nav-bar-connections
# Error accessing https://www.healthline.comhttps://www.bezzyibd.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzyibd.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDC950>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzypsa.com/lp/4/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzypsa.com/lp/4/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBE550>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzypsa.com/lp/4/?utm_source=healthline&utm_medium=nav-bar-connections
# Error accessing https://www.healthline.comhttps://www.bezzypsa.com/lp/4/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzypsa.com/lp/4/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF401A10>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzymigraine.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzymigraine.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15ECC90>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzymigraine.com/?utm_source=healthline&utm_medium=nav-bar-connections
# Error accessing https://www.healthline.comhttps://www.bezzymigraine.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzymigraine.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F061C110>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzyms.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzyms.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EE810>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzyms.com/?utm_source=healthline&utm_medium=nav-bar-connections
# Error accessing https://www.healthline.comhttps://www.bezzyms.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzyms.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15ED5D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.bezzypsoriasis.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzypsoriasis.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF401550>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.bezzypsoriasis.com/?utm_source=healthline&utm_medium=nav-bar-connections
# Error accessing https://www.healthline.comhttps://www.bezzypsoriasis.com/?utm_source=healthline&utm_medium=nav-bar-connections: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.bezzypsoriasis.com/?utm_source=healthline&utm_medium=nav-bar-connections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDF1D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDF290>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/
# Error accessing https://www.healthline.comhttps://www.healthline.com/: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF403290>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EE2D0>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EE490>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/motivation: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/motivation (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F061CE50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/motivation
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/motivation: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/motivation (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0FBFE50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/cardio: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/cardio (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EEF50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/cardio
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/cardio: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/cardio (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF370110>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/strength-training: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/strength-training (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDD250>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/strength-training
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/strength-training: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/strength-training (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F061F450>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/yoga: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/yoga (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EEA50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/yoga
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/yoga: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/yoga (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EFD90>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/recovery: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/recovery (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDFC50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/recovery
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/recovery: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/recovery (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF402250>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/holistic-fitness: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/holistic-fitness (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDEF50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/holistic-fitness
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/holistic-fitness: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/holistic-fitness (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDC510>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/exercise-library: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/exercise-library (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EF990>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/exercise-library
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/exercise-library: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/exercise-library (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15ED950>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/fitness-news: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/fitness-news (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BA1210>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/fitness-news
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/fitness-news: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/fitness-news (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7EF403590>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/fitness-products: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/fitness-products (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15ED410>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/fitness/fitness-products
# Error accessing https://www.healthline.comhttps://www.healthline.com/fitness/fitness-products: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/fitness/fitness-products (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F15EED90>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDD250>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills
# Error accessing https://www.healthline.comhttps://www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BA0910>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Error accessing https://www.healthline.comhttps://www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDF250>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))
# Scraping https://www.healthline.comhttps://www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills
# Error accessing https://www.healthline.comhttps://www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills: HTTPSConnectionPool(host='www.healthline.comhttps', port=443): Max retries exceeded with url: //www.healthline.com/health/how-to-ask-your-doctor-for-weight-loss-pills (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D7F0BDEA50>: Failed to resolve 'www.healthline.comhttps' ([Errno 11001] getaddrinfo failed)"))

# %%
def scrape_and_calculate_statistics(urls_and_texts):
    all_statistics = []
    total_statistics = {
        "num_sentences": 0,
        "num_words": 0,
        "avg_word_length": 0,
        "lexical_diversity": 0,
        "percent_stop_words": 0,
        "noun_count": 0,
    }

    for url, text1 in urls_and_texts:
        # Skip if text1 is None (indicating an issue with fetching the page content)
        if text1 is None:
            print(f"Skipping {url} due to missing page content.")
            continue
        original_sentence = sent_tokenize(text1)
        text1_clean= re.sub(r'[^\w\s]', '', text1 ) # Remove punctuation

        # Tokenize the text
        sentences = sent_tokenize(text1_clean.lower())
        words = word_tokenize(text1_clean.lower())



        # Remove stop words and calculate the percentage of stop words
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        percent_stop_words = (len(words) - len(filtered_words)) / len(words) * 100 if len(words) > 0 else 0

        # Calculate NLP statistics
        num_sentences = len(original_sentence)
        num_words = len(words)

        # Calculate average word length
        avg_word_length = sum(len(word) for word in words) / num_words if num_words > 0 else 0

        # Calculate lexical diversity
        lexical_diversity = len(set(words)) / num_words if num_words > 0 else 0

        # Calculate the frequency distribution of words
        fdist = FreqDist(filtered_words)
        common_words = fdist.most_common(5)  # Get the 5 most common words

        # # Remove stop words and calculate the percentage of stop words
        # stop_words = set(stopwords.words('english'))
        # filtered_words = [word for word in words if word.lower() not in stop_words]
        # percent_stop_words = (len(words) - len(filtered_words)) / len(words) * 100 if len(words) > 0 else 0

        # Part of Speech tagging
        pos_tags = pos_tag(filtered_words)
        noun_count = sum(1 for word, pos in pos_tags if pos in ['NN', 'NNS'])

        # Store the results in a file
        with open('nlp_statistics.txt', 'a') as file:
            file.write(f"URL: {url}\n")
            file.write(f"Number of Sentences: {num_sentences}\n")
            file.write(f"Number of Words: {num_words}\n")
            file.write(f"Average Word Length: {avg_word_length:.2f}\n")
            file.write(f"Lexical Diversity: {lexical_diversity:.2%}\n")
            file.write(f"Common Words: {common_words}\n")
            file.write(f"Percentage of Stop Words: {percent_stop_words:.2f}%\n")
            file.write(f"Noun Count: {noun_count}\n")
            file.write("\n")  # Add a separator between entries

        statistics = {
            "url": url,
            "num_sentences": num_sentences,
            "num_words": num_words,
            "avg_word_length": avg_word_length,
            "lexical_diversity": lexical_diversity,
            "common_words": common_words,
            "percent_stop_words": percent_stop_words,
            "noun_count": noun_count,
        }

        all_statistics.append(statistics)

        total_statistics["num_sentences"] += statistics["num_sentences"]
        total_statistics["num_words"] += statistics["num_words"]
        total_statistics["avg_word_length"] += statistics["avg_word_length"]
        total_statistics["lexical_diversity"] += statistics["lexical_diversity"]
        total_statistics["percent_stop_words"] += statistics["percent_stop_words"]
        total_statistics["noun_count"] += statistics["noun_count"]

        num_pages = len(urls_and_texts)
        if num_pages > 0:
            total_statistics["avg_word_length"] /= num_pages
            total_statistics["lexical_diversity"] /= num_pages
            total_statistics["percent_stop_words"] /= num_pages

    return all_statistics,total_statistics


def write_aggregated_results_to_file(filename, total_statistics):
    with open(filename, 'w') as file:
        file.write("Aggregated Results\n")
        file.write("==================\n")
        file.write(f"Average Number of Sentences: {total_statistics['num_sentences']}\n")
        file.write(f"Average Number of Words: {total_statistics['num_words']}\n")
        file.write(f"Average Average Word Length: {total_statistics['avg_word_length']:.2f}\n")
        file.write(f"Average Lexical Diversity: {total_statistics['lexical_diversity']:.2%}\n")
        file.write(f"Average Percentage of Stop Words: {total_statistics['percent_stop_words']:.2f}%\n")
        file.write(f"Average Noun Count: {total_statistics['noun_count']}\n")

# %%
# Assuming result_text_collection is a list of text content
text_collection_size = len(result_text_collection)
urls = [f"{base_url}{i}" for i in range(1, text_collection_size + 1)]

# Combine URLs and corresponding text content into a list of tuples
urls_and_texts = list(zip(urls, result_text_collection))

# Call the function with the list of tuples
all_statistics,total_stats = scrape_and_calculate_statistics(urls_and_texts)
write_aggregated_results_to_file('aggregated_results.txt', total_stats)

print(all_statistics)


# Now 'all_statistics' contains a list of dictionaries with the calculated statistics for each URL.
# You can use this list as needed.
# Out:
# Skipping https://www.healthline.com/64 due to missing page content.
# Skipping https://www.healthline.com/65 due to missing page content.
# Skipping https://www.healthline.com/66 due to missing page content.
# Skipping https://www.healthline.com/67 due to missing page content.
# Skipping https://www.healthline.com/68 due to missing page content.
# Skipping https://www.healthline.com/69 due to missing page content.
# Skipping https://www.healthline.com/70 due to missing page content.
# Skipping https://www.healthline.com/71 due to missing page content.
# Skipping https://www.healthline.com/76 due to missing page content.
# Skipping https://www.healthline.com/77 due to missing page content.
# Skipping https://www.healthline.com/78 due to missing page content.
# Skipping https://www.healthline.com/80 due to missing page content.
# Skipping https://www.healthline.com/81 due to missing page content.
# Skipping https://www.healthline.com/82 due to missing page content.
# Skipping https://www.healthline.com/83 due to missing page content.
# Skipping https://www.healthline.com/84 due to missing page content.
# Skipping https://www.healthline.com/85 due to missing page content.
# Skipping https://www.healthline.com/86 due to missing page content.
# Skipping https://www.healthline.com/87 due to missing page content.
# Skipping https://www.healthline.com/88 due to missing page content.
# Skipping https://www.healthline.com/89 due to missing page content.
# Skipping https://www.healthline.com/90 due to missing page content.
# Skipping https://www.healthline.com/91 due to missing page content.
# Skipping https://www.healthline.com/92 due to missing page content.
# Skipping https://www.healthline.com/93 due to missing page content.
# Skipping https://www.healthline.com/94 due to missing page content.
# Skipping https://www.healthline.com/95 due to missing page content.
# Skipping https://www.healthline.com/96 due to missing page content.
# Skipping https://www.healthline.com/97 due to missing page content.
# Skipping https://www.healthline.com/98 due to missing page content.
# Skipping https://www.healthline.com/99 due to missing page content.
# Skipping https://www.healthline.com/100 due to missing page content.
# [{'url': 'https://www.healthline.com/1', 'num_sentences': 15, 'num_words': 417, 'avg_word_length': 7.462829736211031, 'lexical_diversity': 0.645083932853717, 'common_words': [('healthline', 6), ('medical', 6), ('information', 5), ('health', 4), ('media', 4)], 'percent_stop_words': 31.894484412470025, 'noun_count': 154}, {'url': 'https://www.healthline.com/2', 'num_sentences': 12, 'num_words': 275, 'avg_word_length': 9.247272727272728, 'lexical_diversity': 0.6618181818181819, 'common_words': [('healthline', 5), ('support', 5), ('information', 4), ('media', 4), ('see', 4)], 'percent_stop_words': 25.454545454545453, 'noun_count': 121}, {'url': 'https://www.healthline.com/3', 'num_sentences': 46, 'num_words': 1497, 'avg_word_length': 6.339345357381429, 'lexical_diversity': 0.41148964595858384, 'common_words': [('breast', 112), ('cancer', 84), ('learn', 14), ('treatment', 13), ('risk', 12)], 'percent_stop_words': 33.60053440213761, 'noun_count': 568}, {'url': 'https://www.healthline.com/4', 'num_sentences': 33, 'num_words': 1200, 'avg_word_length': 6.400833333333333, 'lexical_diversity': 0.4633333333333333, 'common_words': [('disease', 27), ('ulcerative', 24), ('colitis', 24), ('bowel', 20), ('ibd', 15)], 'percent_stop_words': 32.58333333333333, 'noun_count': 409}, {'url': 'https://www.healthline.com/5', 'num_sentences': 34, 'num_words': 1066, 'avg_word_length': 6.518761726078799, 'lexical_diversity': 0.4793621013133208, 'common_words': [('migraine', 57), ('may', 18), ('chronic', 11), ('treatment', 8), ('symptoms', 7)], 'percent_stop_words': 35.17823639774859, 'noun_count': 374}, {'url': 'https://www.healthline.com/6', 'num_sentences': 41, 'num_words': 1395, 'avg_word_length': 6.240143369175628, 'lexical_diversity': 0.4444444444444444, 'common_words': [('ms', 57), ('multiple', 55), ('sclerosis', 53), ('people', 15), ('symptoms', 13)], 'percent_stop_words': 34.26523297491039, 'noun_count': 464}, {'url': 'https://www.healthline.com/7', 'num_sentences': 39, 'num_words': 1181, 'avg_word_length': 6.557154953429297, 'lexical_diversity': 0.43691786621507195, 'common_words': [('arthritis', 52), ('rheumatoid', 30), ('ra', 17), ('pain', 16), ('help', 15)], 'percent_stop_words': 34.462320067739206, 'noun_count': 415}, {'url': 'https://www.healthline.com/8', 'num_sentences': 91, 'num_words': 2115, 'avg_word_length': 5.552245862884161, 'lexical_diversity': 0.29929078014184396, 'common_words': [('diabetes', 56), ('2', 34), ('type', 31), ('blood', 30), ('sugar', 28)], 'percent_stop_words': 36.21749408983452, 'noun_count': 613}, {'url': 'https://www.healthline.com/9', 'num_sentences': 13, 'num_words': 455, 'avg_word_length': 8.32967032967033, 'lexical_diversity': 0.6923076923076923, 'common_words': [('healthline', 5), ('information', 5), ('medical', 4), ('health', 4), ('guide', 4)], 'percent_stop_words': 24.395604395604394, 'noun_count': 170}, {'url': 'https://www.healthline.com/10', 'num_sentences': 12, 'num_words': 289, 'avg_word_length': 12.982698961937716, 'lexical_diversity': 0.7854671280276817, 'common_words': [('information', 4), ('healthline', 4), ('media', 4), ('see', 4), ('additional', 4)], 'percent_stop_words': 13.84083044982699, 'noun_count': 143}, {'url': 'https://www.healthline.com/11', 'num_sentences': 79, 'num_words': 2194, 'avg_word_length': 6.100273473108477, 'lexical_diversity': 0.3878760255241568, 'common_words': [('may', 41), ('gerd', 36), ('symptoms', 28), ('reflux', 26), ('acid', 22)], 'percent_stop_words': 35.961713764813126, 'noun_count': 668}, {'url': 'https://www.healthline.com/12', 'num_sentences': 158, 'num_words': 3319, 'avg_word_length': 6.069297981319675, 'lexical_diversity': 0.3365471527568545, 'common_words': [('adhd', 108), ('may', 27), ('symptoms', 24), ('help', 22), ('children', 21)], 'percent_stop_words': 38.65622175354022, 'noun_count': 986}, {'url': 'https://www.healthline.com/13', 'num_sentences': 151, 'num_words': 2790, 'avg_word_length': 6.225806451612903, 'lexical_diversity': 0.35304659498207885, 'common ...

# %%
print(total_stats)
# Out:
# {'num_sentences': 4343, 'num_words': 108742, 'avg_word_length': 0.09571807519822663, 'lexical_diversity': 0.007013769791481089, 'percent_stop_words': 0.26050016476486787, 'noun_count': 34032}
